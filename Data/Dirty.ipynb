# %%
import pandas as pd 

dirty=pd.read_excel("Dirty Data (1).xlsx")

# %%
dirty
# Out:
#    Bio data with information on name, Email, age, City of Birth, and Gender
# 0   ruqayyah salihu-ibrahimEmailruqayyahsalihu@@gm...
# 1   isere clementEmailisere@@gmail.com29;#YearsIwo...
# 2   mosunmola adenijiEmailmosunmola@@gmail.com17;#...
# 3   olumuyiwa oyebamijiEmailolumuyiwa@@gmail.com17...
# 4   ibrahim rahmanEmailibrahim@@gmail.com28;#Years...
# 5   ibrahim alarapeEmailibrahim@@gmail.com30;#Year...
# 6   kolawole nayinmotEmailkolawole@@gmail.com26;#Y...
# 7   temitope agudaEmailtemitope@@gmail.com23;#Year...
# 8   oladepo kehinde abdulsemiuEmailoladepokehinde@...
# 9   tijani muhydeenEmailtijaniokuwafemi@@gmail.com...
# 10  adebayo abdulrahmanEmailadebayoabdulrahman@@gm...
# 11  abdulwahab mustaphaEmailabdulwahab@@gmail.com2...
# 12  adisa muritalaEmailadisa@@gmail.com29;#YearsIf...
# 13  atitebi zaynabEmailatitebizaynab@@gmail.com28;...
# 14  hassana abdulkadirEmailhassana@@gmail.com16;#Y...
# 15  asmau nurainEmailasmau@@gmail.com27;#YearsMush...
# ...

# %%
dirty.insert(0, "Fullname", dirty["Bio data with information on name, Email, age, City of Birth, and Gender"].str.split("Email").str[0])

# %%
dirty
# Out:
#                       Fullname  \
# 0      ruqayyah salihu-ibrahim
# 1                isere clement
# 2            mosunmola adeniji
# 3          olumuyiwa oyebamiji
# 4               ibrahim rahman
# 5              ibrahim alarape
# 6            kolawole nayinmot
# 7               temitope aguda
# 8   oladepo kehinde abdulsemiu
# 9              tijani muhydeen
# 10         adebayo abdulrahman
# 11         abdulwahab mustapha
# 12              adisa muritala
# 13              atitebi zaynab
# 14          hassana abdulkadir
# 15                asmau nurain
# 16              afolabi saheed
# 17                tolu popoola
# 18         rohemot abdulkareem
# 19   ashimiyu-abdusalam zainab
# 20              adesanya mueez
#
#    Bio data with information on name, Email, age, City of Birth, and Gender
# 0   ruqayyah salihu-ibrahimEmailruqayyahsalihu@@gm...
# 1   isere clementEmailisere@@gmail.com29;#YearsIwo...
# 2   mosunmola adenijiEmailmosunmola@@gmail.com17;#...
# ...

# %%
dirty.columns
# Out:
# Index(['Fullname', 'Bio data with information on name, Email, age, City of Birth, and Gender'], dtype='object')

# %%
dirty["Bio data with information on name, Email, age, City of Birth, and Gender"] = dirty["Bio data with information on name, Email, age, City of Birth, and Gender"].str.split("Email").str[1]

# %%
dirty
# Out:
#                       Fullname  \
# 0      ruqayyah salihu-ibrahim
# 1                isere clement
# 2            mosunmola adeniji
# 3          olumuyiwa oyebamiji
# 4               ibrahim rahman
# 5              ibrahim alarape
# 6            kolawole nayinmot
# 7               temitope aguda
# 8   oladepo kehinde abdulsemiu
# 9              tijani muhydeen
# 10         adebayo abdulrahman
# 11         abdulwahab mustapha
# 12              adisa muritala
# 13              atitebi zaynab
# 14          hassana abdulkadir
# 15                asmau nurain
# 16              afolabi saheed
# 17                tolu popoola
# 18         rohemot abdulkareem
# 19   ashimiyu-abdusalam zainab
# 20              adesanya mueez
#
#    Bio data with information on name, Email, age, City of Birth, and Gender
# 0    ruqayyahsalihu@@gmail.com21;#YearsIfe GenderMale
# 1             isere@@gmail.com29;#YearsIwo GenderMale
# 2       mosunmola@@gmail.com17;#YearsIla GenderFemale
# ...

# %%
dirty.insert(1, "Email", dirty["Bio data with information on name, Email, age, City of Birth, and Gender"].str.split("\d+").str[0])

# %%
dirty
# Out:
#                       Fullname                          Email  \
# 0      ruqayyah salihu-ibrahim      ruqayyahsalihu@@gmail.com
# 1                isere clement               isere@@gmail.com
# 2            mosunmola adeniji           mosunmola@@gmail.com
# 3          olumuyiwa oyebamiji           olumuyiwa@@gmail.com
# 4               ibrahim rahman             ibrahim@@gmail.com
# 5              ibrahim alarape             ibrahim@@gmail.com
# 6            kolawole nayinmot            kolawole@@gmail.com
# 7               temitope aguda            temitope@@gmail.com
# 8   oladepo kehinde abdulsemiu      oladepokehinde@@gmail.com
# 9              tijani muhydeen     tijaniokuwafemi@@gmail.com
# 10         adebayo abdulrahman  adebayoabdulrahman@@gmail.com
# 11         abdulwahab mustapha          abdulwahab@@gmail.com
# 12              adisa muritala               adisa@@gmail.com
# 13              atitebi zaynab       atitebizaynab@@gmail.com
# ...

# %%
dirty["Email"]=dirty["Email"].str.replace("@@","@",regex=False)

# %%
dirty
# Out:
#                       Fullname                         Email  \
# 0      ruqayyah salihu-ibrahim      ruqayyahsalihu@gmail.com
# 1                isere clement               isere@gmail.com
# 2            mosunmola adeniji           mosunmola@gmail.com
# 3          olumuyiwa oyebamiji           olumuyiwa@gmail.com
# 4               ibrahim rahman             ibrahim@gmail.com
# 5              ibrahim alarape             ibrahim@gmail.com
# 6            kolawole nayinmot            kolawole@gmail.com
# 7               temitope aguda            temitope@gmail.com
# 8   oladepo kehinde abdulsemiu      oladepokehinde@gmail.com
# 9              tijani muhydeen     tijaniokuwafemi@gmail.com
# 10         adebayo abdulrahman  adebayoabdulrahman@gmail.com
# 11         abdulwahab mustapha          abdulwahab@gmail.com
# 12              adisa muritala               adisa@gmail.com
# 13              atitebi zaynab       atitebizaynab@gmail.com
# ...

# %%
dirty["Bio data with information on name, Email, age, City of Birth, and Gender"] =dirty["Bio data with information on name, Email, age, City of Birth, and Gender"].str.split(".com").str[1]

# %%
dirty
# Out:
#                       Fullname                         Email  \
# 0      ruqayyah salihu-ibrahim      ruqayyahsalihu@gmail.com
# 1                isere clement               isere@gmail.com
# 2            mosunmola adeniji           mosunmola@gmail.com
# 3          olumuyiwa oyebamiji           olumuyiwa@gmail.com
# 4               ibrahim rahman             ibrahim@gmail.com
# 5              ibrahim alarape             ibrahim@gmail.com
# 6            kolawole nayinmot            kolawole@gmail.com
# 7               temitope aguda            temitope@gmail.com
# 8   oladepo kehinde abdulsemiu      oladepokehinde@gmail.com
# 9              tijani muhydeen     tijaniokuwafemi@gmail.com
# 10         adebayo abdulrahman  adebayoabdulrahman@gmail.com
# 11         abdulwahab mustapha          abdulwahab@gmail.com
# 12              adisa muritala               adisa@gmail.com
# 13              atitebi zaynab       atitebizaynab@gmail.com
# ...

# %%
dirty.insert(2, "Gender", dirty["Bio data with information on name, Email, age, City of Birth, and Gender"].str.split(";#").str[0])

# %%
dirty
# Out:
#                       Fullname                         Email Gender  \
# 0      ruqayyah salihu-ibrahim      ruqayyahsalihu@gmail.com     21
# 1                isere clement               isere@gmail.com     29
# 2            mosunmola adeniji           mosunmola@gmail.com     17
# 3          olumuyiwa oyebamiji           olumuyiwa@gmail.com     17
# 4               ibrahim rahman             ibrahim@gmail.com     28
# 5              ibrahim alarape             ibrahim@gmail.com     30
# 6            kolawole nayinmot            kolawole@gmail.com     26
# 7               temitope aguda            temitope@gmail.com     23
# 8   oladepo kehinde abdulsemiu      oladepokehinde@gmail.com     15
# 9              tijani muhydeen     tijaniokuwafemi@gmail.com     20
# 10         adebayo abdulrahman  adebayoabdulrahman@gmail.com     24
# 11         abdulwahab mustapha          abdulwahab@gmail.com     20
# 12              adisa muritala               adisa@gmail.com     29
# ...

# %%
dirty["Bio data with information on name, Email, age, City of Birth, and Gender"] = dirty["Bio data with information on name, Email, age, City of Birth, and Gender"].str.split("Years").str[1]

# %%
dirty
# Out:
#                       Fullname                         Email Gender  \
# 0      ruqayyah salihu-ibrahim      ruqayyahsalihu@gmail.com     21
# 1                isere clement               isere@gmail.com     29
# 2            mosunmola adeniji           mosunmola@gmail.com     17
# 3          olumuyiwa oyebamiji           olumuyiwa@gmail.com     17
# 4               ibrahim rahman             ibrahim@gmail.com     28
# 5              ibrahim alarape             ibrahim@gmail.com     30
# 6            kolawole nayinmot            kolawole@gmail.com     26
# 7               temitope aguda            temitope@gmail.com     23
# 8   oladepo kehinde abdulsemiu      oladepokehinde@gmail.com     15
# 9              tijani muhydeen     tijaniokuwafemi@gmail.com     20
# 10         adebayo abdulrahman  adebayoabdulrahman@gmail.com     24
# 11         abdulwahab mustapha          abdulwahab@gmail.com     20
# 12              adisa muritala               adisa@gmail.com     29
# ...

# %%
dirty.insert(3, "City", dirty["Bio data with information on name, Email, age, City of Birth, and Gender"].str.split("Gender").str[0])

# %%
dirty
# Out:
#                       Fullname                         Email Gender  \
# 0      ruqayyah salihu-ibrahim      ruqayyahsalihu@gmail.com     21
# 1                isere clement               isere@gmail.com     29
# 2            mosunmola adeniji           mosunmola@gmail.com     17
# 3          olumuyiwa oyebamiji           olumuyiwa@gmail.com     17
# 4               ibrahim rahman             ibrahim@gmail.com     28
# 5              ibrahim alarape             ibrahim@gmail.com     30
# 6            kolawole nayinmot            kolawole@gmail.com     26
# 7               temitope aguda            temitope@gmail.com     23
# 8   oladepo kehinde abdulsemiu      oladepokehinde@gmail.com     15
# 9              tijani muhydeen     tijaniokuwafemi@gmail.com     20
# 10         adebayo abdulrahman  adebayoabdulrahman@gmail.com     24
# 11         abdulwahab mustapha          abdulwahab@gmail.com     20
# 12              adisa muritala               adisa@gmail.com     29
# ...

# %%
dirty.insert(2,"Age",dirty["Gender"])

# %%
del dirty["Gender"]

# %%
dirty
# Out:
#                       Fullname                         Email Age        City  \
# 0      ruqayyah salihu-ibrahim      ruqayyahsalihu@gmail.com  21        Ife
# 1                isere clement               isere@gmail.com  29        Iwo
# 2            mosunmola adeniji           mosunmola@gmail.com  17        Ila
# 3          olumuyiwa oyebamiji           olumuyiwa@gmail.com  17     Ibadan
# 4               ibrahim rahman             ibrahim@gmail.com  28      Ikeja
# 5              ibrahim alarape             ibrahim@gmail.com  30    Ikorodu
# 6            kolawole nayinmot            kolawole@gmail.com  26       Ketu
# 7               temitope aguda            temitope@gmail.com  23     Somolu
# 8   oladepo kehinde abdulsemiu      oladepokehinde@gmail.com  15  Alimosoho
# 9              tijani muhydeen     tijaniokuwafemi@gmail.com  20     Osogbo
# 10         adebayo abdulrahman  adebayoabdulrahman@gmail.com  24      Ikire
# ...

# %%
dirty["Bio data with information on name, Email, age, City of Birth, and Gender"] = dirty["Bio data with information on name, Email, age, City of Birth, and Gender"].str.split("Gender").str[1]

# %%
dirty
# Out:
#                       Fullname                         Email Age        City  \
# 0      ruqayyah salihu-ibrahim      ruqayyahsalihu@gmail.com  21        Ife
# 1                isere clement               isere@gmail.com  29        Iwo
# 2            mosunmola adeniji           mosunmola@gmail.com  17        Ila
# 3          olumuyiwa oyebamiji           olumuyiwa@gmail.com  17     Ibadan
# 4               ibrahim rahman             ibrahim@gmail.com  28      Ikeja
# 5              ibrahim alarape             ibrahim@gmail.com  30    Ikorodu
# 6            kolawole nayinmot            kolawole@gmail.com  26       Ketu
# 7               temitope aguda            temitope@gmail.com  23     Somolu
# 8   oladepo kehinde abdulsemiu      oladepokehinde@gmail.com  15  Alimosoho
# 9              tijani muhydeen     tijaniokuwafemi@gmail.com  20     Osogbo
# 10         adebayo abdulrahman  adebayoabdulrahman@gmail.com  24      Ikire
# ...

# %%
dirty.insert(4,"Gender",dirty["Bio data with information on name, Email, age, City of Birth, and Gender"])

# %%
del dirty["Bio data with information on name, Email, age, City of Birth, and Gender"]

# %%
dirty
# Out:
#                       Fullname                         Email Age        City  \
# 0      ruqayyah salihu-ibrahim      ruqayyahsalihu@gmail.com  21        Ife
# 1                isere clement               isere@gmail.com  29        Iwo
# 2            mosunmola adeniji           mosunmola@gmail.com  17        Ila
# 3          olumuyiwa oyebamiji           olumuyiwa@gmail.com  17     Ibadan
# 4               ibrahim rahman             ibrahim@gmail.com  28      Ikeja
# 5              ibrahim alarape             ibrahim@gmail.com  30    Ikorodu
# 6            kolawole nayinmot            kolawole@gmail.com  26       Ketu
# 7               temitope aguda            temitope@gmail.com  23     Somolu
# 8   oladepo kehinde abdulsemiu      oladepokehinde@gmail.com  15  Alimosoho
# 9              tijani muhydeen     tijaniokuwafemi@gmail.com  20     Osogbo
# 10         adebayo abdulrahman  adebayoabdulrahman@gmail.com  24      Ikire
# ...

# %%
dirty["Fullname"]=dirty["Fullname"].str.title()

# %%
dirty
# Out:
#                       Fullname                         Email Age        City  \
# 0      Ruqayyah Salihu-Ibrahim      ruqayyahsalihu@gmail.com  21        Ife
# 1                Isere Clement               isere@gmail.com  29        Iwo
# 2            Mosunmola Adeniji           mosunmola@gmail.com  17        Ila
# 3          Olumuyiwa Oyebamiji           olumuyiwa@gmail.com  17     Ibadan
# 4               Ibrahim Rahman             ibrahim@gmail.com  28      Ikeja
# 5              Ibrahim Alarape             ibrahim@gmail.com  30    Ikorodu
# 6            Kolawole Nayinmot            kolawole@gmail.com  26       Ketu
# 7               Temitope Aguda            temitope@gmail.com  23     Somolu
# 8   Oladepo Kehinde Abdulsemiu      oladepokehinde@gmail.com  15  Alimosoho
# 9              Tijani Muhydeen     tijaniokuwafemi@gmail.com  20     Osogbo
# 10         Adebayo Abdulrahman  adebayoabdulrahman@gmail.com  24      Ikire
# ...
